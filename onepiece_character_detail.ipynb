# %%
# Import necessary packages for web scraping
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Read data from 'one_piece_characters.csv' into a dataframe 
op_names = pd.read_csv('one_piece_characters.csv')

name_list = []

for name in op_names['Name'].tolist():
    formatted_name = name.replace(' ', '_')
    
    URL = "https://onepiece.fandom.com/wiki/" + formatted_name
    try:
        r = requests.get(URL)
        r.raise_for_status()
        
        soup = BeautifulSoup(r.content, 'html.parser')
        table_statistics = soup.find('aside', attrs={'class': 'portable-infobox'}).findAll('section')
        
        # Character Data
        character_data = {}
        for section in table_statistics[:1]:
            for item in section.findAll('div', {'class': 'pi-item'}):
                label = item.find('h3', class_='pi-data-label').text.strip()
                value = item.find('div', class_='pi-data-value').text.strip()
                character_data[label] = value
        
        # Devil Fruit Data
        devil_fruit_data = {}
        for section in table_statistics[1:]:
            for item in section.findAll('div', {'class': 'pi-item'}):
                label = 'Devil Fruit ' + item.find('h3', class_='pi-data-label').text.strip()
                value = item.find('div', class_='pi-data-value').text.strip()
                devil_fruit_data[label] = value
        
        # Merge character_data and devil_fruit_data
        all_data = {**character_data, **devil_fruit_data}
        
        data_details = {name: all_data}
        name_list.append(data_details)
        
    except requests.exceptions.HTTPError as e:
        print("Error " + name)

    except Exception as e:
        print("An unexpected error occurred for {}: {}".format(name, str(e)))
        
print("Finished scrapping")
# Out:
# Error Jack-in-the-Box
# An unexpected error occurred for Minatomo: 'NoneType' object has no attribute 'findAll'
# An unexpected error occurred for Minatomo: 'NoneType' object has no attribute 'findAll'
# Error Mr. Sacrifice
# Error Wall Zombie
# Finished scrapping

# %%
print(name_list[0])
# Out:
# {'A O': {'Japanese Name:': 'A・O', 'Romanized Name:': 'Ā Ō', 'Official English Name:': 'A.O. (VIZ Media and FUNimation subs);A.O (FUNimation dub)', 'Debut:': 'Chapter 551; Episode 460[1]', 'Affiliations:': 'A O Pirates;[2] Subordinate of the Whitebeard Pirates[1][2]', 'Occupations:': 'Pirate; Captain[1][2]', 'Status:': 'Unknown', 'Birthday:': 'January 15th[3]', 'Japanese VA:': 'Kōhei Fukuhara', 'Funi English VA:': 'Mark Fickert'}}

# %%
# Create a dataframe with the combined data.
df = pd.concat([pd.DataFrame(result) for result in name_list], axis=1)
df = df.transpose()

df.head(3)
# Out:
#                                               Affiliations:         Birthday:  \
# A O       A O Pirates;[2] Subordinate of the Whitebeard ...   January 15th[3]
# Abdullah       Ideo Pirates[2][3]; Straw Hat Grand Fleet[4]               NaN
# Absalom   Thriller Bark Pirates (Mysterious Four)[2] (fo...  December 30th[5]
#
#                                Debut: Funi English VA: Japanese Name:  \
# A O       Chapter 551; Episode 460[1]     Mark Fickert            A・O
# Abdullah  Chapter 704; Episode 633[1]    Sean O'Connor          アブドーラ
# Absalom   Chapter 444; Episode 339[1]  Andrew Chandler          アブサロム
#
#             Japanese VA:                                       Occupations:  \
# A O       Kōhei Fukuhara                              Pirate; Captain[1][2]
# Abdullah     Keiji Hirai     Pirate[3], Criminal; Bounty Hunter (former)[1]
# Absalom    Hiroaki Miura  Reporter[3]Soldier Zombie and General Zombie L...
#
#                                      Official English Name: Romanized Name:  \
# A O       A.O. (VIZ Media and FUNimation subs);A.O (FUNi...             Ā Ō
# Abdullah                                           Abdullah         Abudōra
# Absalom                                             Absalom       Abusaromu
#
#            Status:  ... Features: Devil Fruit Affiliations:  \
# A O        Unknown  ...       NaN                       NaN
# Abdullah     Alive  ...       NaN                       NaN
# Absalom   Deceased  ...       NaN                       NaN
#
#          Devil Fruit Funi English VA: Devil Fruit Japanese VA: Homeland:  \
# A O                               NaN                      NaN       NaN
# Abdullah                          NaN                      NaN       NaN
# Absalom                           NaN                      NaN       NaN
#
#          Captain: Total Bounty: Fighting Style Focus: Literal Meaning:  \
# A O           NaN           NaN                   NaN              NaN
# Abdullah      NaN           NaN                   NaN              NaN
# Absalom       NaN           NaN                   NaN              NaN
#
#          User(s):
# A O           NaN
# Abdullah      NaN
# Absalom       NaN
#
# [3 rows x 61 columns]

# %%
# Display information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1376 entries, A O to Zunesha
# Data columns (total 61 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Affiliations:                       1169 non-null   object
#  1   Birthday:                           712 non-null    object
#  2   Debut:                              1351 non-null   object
#  3   Funi English VA:                    940 non-null    object
#  4   Japanese Name:                      1369 non-null   object
#  5   Japanese VA:                        1004 non-null   object
#  6   Occupations:                        1162 non-null   object
#  7   Official English Name:              1366 non-null   object
#  8   Romanized Name:                     1367 non-null   object
#  9   Status:                             1350 non-null   object
#  10  Age at Death:                       39 non-null     object
#  11  Age:                                460 non-null    object
#  12  Alias:                              86 non-null     object
#  13  Blood Type:                         394 non-null    object
#  14  Devil Fruit English Name:           176 non-null    object
#  15  Devil Fruit Japanese Name:          160 non-null    object
#  16  Devil Fruit Meaning:                151 non-null    object
#  17  Devil Fruit Type:                   183 non-null    object
#  18  Epithet:                            252 non-null    object
#  19  Height:                             397 non-null    object
#  20  Origin:                             502 non-null    object
#  21  Weight:                             6 non-null      object
#  22  Residence:                          516 non-null    object
#  23  Bounty:                             181 non-null    object
#  24  4Kids English VA:                   107 non-null    object
#  25  Live-Action Portrayal:              48 non-null     object
#  26  Odex English VA:                    68 non-null     object
#  27  Birth Name:                         8 non-null      object
#  28  Doriki:                             9 non-null      object
#  29  Gladiator Number:                   6 non-null      object
#  30  Affiliation:                        7 non-null      object
#  31  First Appearance:                   13 non-null     object
#  32  Leader(s):                          6 non-null      object
#  33  Zombie Number:                      8 non-null      object
#  34  CP9 key:                            6 non-null      object
#  35  Devil Fruit First Appearance:       7 non-null      object
#  36  Devil Fruit Official English Name:  7 non-null      object
#  37  Devil Fruit Romanized Name:         7 non-null      object
#  38  Affiliates:                         2 non-null      object
#  39  English Name:                       3 non-null      object
#  40  First appearance:                   3 non-null      object
#  41  Region:                             3 non-null      object
#  42  Completion Date:                    1 non-null      object
#  43  Length:                             1 non-null      object
#  44  Size:                               5 non-null      object
#  45  Devil Fruit Owners:                 1 non-null      object
#  46  Fruit Debut:                        2 non-null      object
#  47  Meaning:                            2 non-null      object
#  48  Previous User:                      2 non-null      object
#  49  Type:                               2 non-null      object
#  50  Usage Debut:                        2 non-null      object
#  51  Features:                           5 non-null      object
#  52  Devil Fruit Affiliations:           1 non-null      object
#  53  Devil Fruit Funi English VA:        1 non-null      object
#  54  Devil Fruit Japanese VA:            1 non-null      object
#  55  Homeland:                           1 non-null      object
#  56  Captain:                            1 non-null      object
#  57  Total Bounty:                       1 non-null      object
#  58  Fighting Style Focus:               1 non-null      object
#  59  Literal Meaning:                    1 non-null      object
#  60  User(s):                            1 non-null      object
# dtypes: object(61)
# memory usage: 666.5+ KB

# %%
# Save dataframe to csv file
csv_file = "onepiece_character_detail.csv"
df.to_csv(csv_file, index=False)
